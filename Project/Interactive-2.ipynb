# %% [markdown]
# Connected to Python 3.10.4

# %%
"""World Sustainability Dataset"""
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# read csv and assign it to variable df
df = pd.read_csv(
    "/workspaces/Data-Analysis-with-Python/Project/WorldSustainabilityDataset.csv"
)
print(df.head())

# only keep country name, year, final consumption expenditure, renewable energy consumption,
# annual CO2 emissions, continent, and income classification
df = df[
    [
        "Country Name",
        "Year",
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes",
        "Continent",
        "Income Classification (World Bank Definition)",
    ]
]

print(df.head())

# rename columns
df.rename(
    columns={
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS": "Final Consumption",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS": "Renewable Energy Consumption",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes": "Annual CO2 Emissions",
        "Income Classification (World Bank Definition)": "Income Classification",
    },
    inplace=True,
)

print(df.head())

# rearrange columns
df = df[
    [
        "Continent",
        "Country Name",
        "Income Classification",
        "Year",
        "Annual CO2 Emissions",
        "Renewable Energy Consumption",
        "Final Consumption",
    ]
]

print(df.head())

# check to see how many null objects are in the dataset
print(df.isnull().sum())

# quick summary of each column in the dataframe
print(df.describe())

# data dimensions
print(df.shape)

# calculate mean of points grouped by continent
print(df.groupby("Continent")["Renewable Energy Consumption"].mean())
# Out:
#   Country Name Country Code  Year
# 0        Aruba          ABW  2000  \
# 1        Aruba          ABW  2001
# 2        Aruba          ABW  2002
# 3        Aruba          ABW  2003
# 4        Aruba          ABW  2004
#
#    Access to electricity (% of population) - EG.ELC.ACCS.ZS
# 0                                          91.660398         \
# 1                                         100.000000
# 2                                         100.000000
# 3                                         100.000000
# 4                                         100.000000
#
#    Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS
# 0                                          15.392211                                           \
# 1                                          11.491930
# 2                                           3.893620
# 3                                           6.713863
# 4                                           9.801576
#
#    Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS
# 0                                           2.389134                       \
# 1                                           2.509046
# 2                                           2.721385
# 3                                           2.733676
# 4                                           2.678363
#
#    Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS
# 0                                           0.000190                             \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS
# 0                                           0.000190                      \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS
# 0                                                NaN                             \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  Gini index (World Bank estimate) - SI.POV.GINI
# 0  ...                                             NaN  \
# 1  ...                                             NaN
# 2  ...                                             NaN
# 3  ...                                             NaN
# 4  ...                                             NaN
#
#    Income Classification (World Bank Definition)
# 0                                    High income  \
# 1                                    High income
# 2                                    High income
# 3                                    High income
# 4                                    High income
#
#    Individuals using the Internet (% of population) - IT.NET.USER.ZS
# 0                                                NaN                  \
# 1                                               17.1
# 2                                               18.8
# 3                                               20.8
# 4                                               23.0
#
#    Life expectancy at birth, total (years) - SP.DYN.LE00.IN
# 0                                                NaN         \
# 1                                             73.853
# 2                                             73.937
# 3                                             74.038
# 4                                             74.156
#
#    Population, total - SP.POP.TOTL  Regime Type (RoW Measure Definition)
# 0                              NaN                                   NaN  \
# 1                          92892.0                                   NaN
# 2                          94992.0                                   NaN
# 3                          97016.0                                   NaN
# 4                          98744.0                                   NaN
#
#    Rural population (% of total population) - SP.RUR.TOTL.ZS
# 0                                             53.283          \
# 1                                             53.661
# 2                                             54.028
# 3                                             54.394
# 4                                             54.760
#
#    Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS
# 0                                                NaN             \
# 1                                           0.000712
# 2                                           0.000657
# 3                                           0.000700
# 4                                           0.000685
#
#    Urban population (% of total population) - SP.URB.TOTL.IN.ZS
# 0                                                NaN             \
# 1                                             46.339
# 2                                             45.972
# 3                                             45.606
# 4                                             45.240
#
#    World Regions (UN SDG Definition)
# 0        Latin America and Caribbean
# 1        Latin America and Caribbean
# 2        Latin America and Caribbean
# 3        Latin America and Caribbean
# 4        Latin America and Caribbean
#
# [5 rows x 54 columns]
#   Country Name  Year
# 0        Aruba  2000  \
# 1        Aruba  2001
# 2        Aruba  2002
# 3        Aruba  2003
# 4        Aruba  2004
#
#    Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS
# 0                                          70.792132          \
# 1                                          74.338086
# 2                                          77.553957
# 3                                          78.551686
# 4                                          74.705440
#
#    Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS
# 0                                             0.1753                                    \
# 1                                             0.1805
# 2                                             0.1814
# 3                                             0.1846
# 4                                             0.1871
#
#    Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes
# 0                                              2.378                                      \
# 1                                              2.407
# 2                                              2.437
# 3                                              2.561
# 4                                              2.616
#
#        Continent Income Classification (World Bank Definition)
# 0  North America                                   High income
# 1  North America                                   High income
# 2  North America                                   High income
# 3  North America                                   High income
# 4  North America                                   High income
#   Country Name  Year  Final Consumption  Renewable Energy Consumption
# 0        Aruba  2000          70.792132                        0.1753  \
# 1        Aruba  2001          74.338086                        0.1805
# 2        Aruba  2002          77.553957                        0.1814
# 3        Aruba  2003          78.551686                        0.1846
# 4        Aruba  2004          74.705440                        0.1871
#
#    Annual CO2 Emissions      Continent Income Classification
# 0                 2.378  North America           High income
# 1                 2.407  North America           High income
# 2                 2.437  North America           High income
# 3                 2.561  North America           High income
# 4                 2.616  North America           High income
#        Continent Country Name Income Classification  Year
# 0  North America        Aruba           High income  2000  \
# 1  North America        Aruba           High income  2001
# 2  North America        Aruba           High income  2002
# 3  North America        Aruba           High income  2003
# 4  North America        Aruba           High income  2004
#
#    Annual CO2 Emissions  Renewable Energy Consumption  Final Consumption
# 0                 2.378                        0.1753          70.792132
# 1                 2.407                        0.1805          74.338086
# 2                 2.437                        0.1814          77.553957
# 3                 2.561                        0.1846          78.551686
# 4                 2.616                        0.1871          74.705440
# Continent                         2
# Country Name                      0
# Income Classification             2
# Year                              0
# Annual CO2 Emissions              2
# Renewable Energy Consumption      0
# Final Consumption               240
# dtype: int64
#               Year  Annual CO2 Emissions  Renewable Energy Consumption
# count  3287.000000           3285.000000                   3287.000000  \
# mean   2009.000000            174.646907                     32.672923
# std       5.478059            757.653194                     29.921274
# min    2000.000000              0.048000                      0.000000
# 25%    2004.000000              2.426000                      6.835400
# 50%    2009.000000             12.621000                     22.659800
# 75%    2014.000000             72.012000                     54.638100
# max    2018.000000           9956.569000                     98.342903
#
#        Final Consumption
# count        3047.000000
# mean           80.410827
# std            19.334168
# min            16.712957
# 25%            71.261800
# 50%            79.509708
# 75%            89.748636
# max           241.973940
# (3287, 7)
# Continent
# Africa           61.446756
# Asia             21.308767
# Europe           18.771750
# North America    23.068256
# Oceania          28.269439
# South America    29.872472
# Name: Renewable Energy Consumption, dtype: float64

# %%
"""World Sustainability Dataset"""
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# read csv and assign it to variable df
df = pd.read_csv(
    "/workspaces/Data-Analysis-with-Python/Project/WorldSustainabilityDataset.csv"
)
print(df.head())

# only keep country name, year, final consumption expenditure, renewable energy consumption,
# annual CO2 emissions, continent, and income classification
df = df[
    [
        "Country Name",
        "Year",
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes",
        "Continent",
        "Income Classification (World Bank Definition)",
    ]
]

print(df.head())

# rename columns
df.rename(
    columns={
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS": "Final Consumption",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS": "Renewable Energy Consumption",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes": "Annual CO2 Emissions",
        "Income Classification (World Bank Definition)": "Income Classification",
    },
    inplace=True,
)

print(df.head())

# rearrange columns
df = df[
    [
        "Continent",
        "Country Name",
        "Income Classification",
        "Year",
        "Annual CO2 Emissions",
        "Renewable Energy Consumption",
        "Final Consumption",
    ]
]

print(df.head())

# check to see how many null objects are in the dataset
print(df.isnull().sum())

# quick summary of each column in the dataframe
print(df.describe())

# data dimensions
print(df.shape)
# Out:
#   Country Name Country Code  Year
# 0        Aruba          ABW  2000  \
# 1        Aruba          ABW  2001
# 2        Aruba          ABW  2002
# 3        Aruba          ABW  2003
# 4        Aruba          ABW  2004
#
#    Access to electricity (% of population) - EG.ELC.ACCS.ZS
# 0                                          91.660398         \
# 1                                         100.000000
# 2                                         100.000000
# 3                                         100.000000
# 4                                         100.000000
#
#    Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS
# 0                                          15.392211                                           \
# 1                                          11.491930
# 2                                           3.893620
# 3                                           6.713863
# 4                                           9.801576
#
#    Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS
# 0                                           2.389134                       \
# 1                                           2.509046
# 2                                           2.721385
# 3                                           2.733676
# 4                                           2.678363
#
#    Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS
# 0                                           0.000190                             \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS
# 0                                           0.000190                      \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS
# 0                                                NaN                             \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  Gini index (World Bank estimate) - SI.POV.GINI
# 0  ...                                             NaN  \
# 1  ...                                             NaN
# 2  ...                                             NaN
# 3  ...                                             NaN
# 4  ...                                             NaN
#
#    Income Classification (World Bank Definition)
# 0                                    High income  \
# 1                                    High income
# 2                                    High income
# 3                                    High income
# 4                                    High income
#
#    Individuals using the Internet (% of population) - IT.NET.USER.ZS
# 0                                                NaN                  \
# 1                                               17.1
# 2                                               18.8
# 3                                               20.8
# 4                                               23.0
#
#    Life expectancy at birth, total (years) - SP.DYN.LE00.IN
# 0                                                NaN         \
# 1                                             73.853
# 2                                             73.937
# 3                                             74.038
# 4                                             74.156
#
#    Population, total - SP.POP.TOTL  Regime Type (RoW Measure Definition)
# 0                              NaN                                   NaN  \
# 1                          92892.0                                   NaN
# 2                          94992.0                                   NaN
# 3                          97016.0                                   NaN
# 4                          98744.0                                   NaN
#
#    Rural population (% of total population) - SP.RUR.TOTL.ZS
# 0                                             53.283          \
# 1                                             53.661
# 2                                             54.028
# 3                                             54.394
# 4                                             54.760
#
#    Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS
# 0                                                NaN             \
# 1                                           0.000712
# 2                                           0.000657
# 3                                           0.000700
# 4                                           0.000685
#
#    Urban population (% of total population) - SP.URB.TOTL.IN.ZS
# 0                                                NaN             \
# 1                                             46.339
# 2                                             45.972
# 3                                             45.606
# 4                                             45.240
#
#    World Regions (UN SDG Definition)
# 0        Latin America and Caribbean
# 1        Latin America and Caribbean
# 2        Latin America and Caribbean
# 3        Latin America and Caribbean
# 4        Latin America and Caribbean
#
# [5 rows x 54 columns]
#   Country Name  Year
# 0        Aruba  2000  \
# 1        Aruba  2001
# 2        Aruba  2002
# 3        Aruba  2003
# 4        Aruba  2004
#
#    Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS
# 0                                          70.792132          \
# 1                                          74.338086
# 2                                          77.553957
# 3                                          78.551686
# 4                                          74.705440
#
#    Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS
# 0                                             0.1753                                    \
# 1                                             0.1805
# 2                                             0.1814
# 3                                             0.1846
# 4                                             0.1871
#
#    Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes
# 0                                              2.378                                      \
# 1                                              2.407
# 2                                              2.437
# 3                                              2.561
# 4                                              2.616
#
#        Continent Income Classification (World Bank Definition)
# 0  North America                                   High income
# 1  North America                                   High income
# 2  North America                                   High income
# 3  North America                                   High income
# 4  North America                                   High income
#   Country Name  Year  Final Consumption  Renewable Energy Consumption
# 0        Aruba  2000          70.792132                        0.1753  \
# 1        Aruba  2001          74.338086                        0.1805
# 2        Aruba  2002          77.553957                        0.1814
# 3        Aruba  2003          78.551686                        0.1846
# 4        Aruba  2004          74.705440                        0.1871
#
#    Annual CO2 Emissions      Continent Income Classification
# 0                 2.378  North America           High income
# 1                 2.407  North America           High income
# 2                 2.437  North America           High income
# 3                 2.561  North America           High income
# 4                 2.616  North America           High income
#        Continent Country Name Income Classification  Year
# 0  North America        Aruba           High income  2000  \
# 1  North America        Aruba           High income  2001
# 2  North America        Aruba           High income  2002
# 3  North America        Aruba           High income  2003
# 4  North America        Aruba           High income  2004
#
#    Annual CO2 Emissions  Renewable Energy Consumption  Final Consumption
# 0                 2.378                        0.1753          70.792132
# 1                 2.407                        0.1805          74.338086
# 2                 2.437                        0.1814          77.553957
# 3                 2.561                        0.1846          78.551686
# 4                 2.616                        0.1871          74.705440
# Continent                         2
# Country Name                      0
# Income Classification             2
# Year                              0
# Annual CO2 Emissions              2
# Renewable Energy Consumption      0
# Final Consumption               240
# dtype: int64
#               Year  Annual CO2 Emissions  Renewable Energy Consumption
# count  3287.000000           3285.000000                   3287.000000  \
# mean   2009.000000            174.646907                     32.672923
# std       5.478059            757.653194                     29.921274
# min    2000.000000              0.048000                      0.000000
# 25%    2004.000000              2.426000                      6.835400
# 50%    2009.000000             12.621000                     22.659800
# 75%    2014.000000             72.012000                     54.638100
# max    2018.000000           9956.569000                     98.342903
#
#        Final Consumption
# count        3047.000000
# mean           80.410827
# std            19.334168
# min            16.712957
# 25%            71.261800
# 50%            79.509708
# 75%            89.748636
# max           241.973940
# (3287, 7)

# %%
"""World Sustainability Dataset"""
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# read csv and assign it to variable df
df = pd.read_csv(
    "/workspaces/Data-Analysis-with-Python/Project/WorldSustainabilityDataset.csv"
)
print(df.head())

# only keep country name, year, final consumption expenditure, renewable energy consumption,
# annual CO2 emissions, continent, and income classification
df = df[
    [
        "Country Name",
        "Year",
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes",
        "Continent",
        "Income Classification (World Bank Definition)",
    ]
]

print(df.head())

# rename columns
df.rename(
    columns={
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS": "Final Consumption",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS": "Renewable Energy Consumption",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes": "Annual CO2 Emissions",
        "Income Classification (World Bank Definition)": "Income Classification",
    },
    inplace=True,
)

print(df.head())

# rearrange columns
df = df[
    [
        "Continent",
        "Country Name",
        "Income Classification",
        "Year",
        "Annual CO2 Emissions",
        "Renewable Energy Consumption",
        "Final Consumption",
    ]
]

print(df.head())

# check to see how many null objects are in the dataset
print(df.isnull().sum())

# quick summary of each column in the dataframe
print(df.describe())

# data dimensions
print(df.shape)

# calculate mean of points grouped by continent
print(df.groupby("Continent")["Renewable Energy Consumption"].mean())
# Out:
#   Country Name Country Code  Year
# 0        Aruba          ABW  2000  \
# 1        Aruba          ABW  2001
# 2        Aruba          ABW  2002
# 3        Aruba          ABW  2003
# 4        Aruba          ABW  2004
#
#    Access to electricity (% of population) - EG.ELC.ACCS.ZS
# 0                                          91.660398         \
# 1                                         100.000000
# 2                                         100.000000
# 3                                         100.000000
# 4                                         100.000000
#
#    Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS
# 0                                          15.392211                                           \
# 1                                          11.491930
# 2                                           3.893620
# 3                                           6.713863
# 4                                           9.801576
#
#    Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS
# 0                                           2.389134                       \
# 1                                           2.509046
# 2                                           2.721385
# 3                                           2.733676
# 4                                           2.678363
#
#    Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS
# 0                                           0.000190                             \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS
# 0                                           0.000190                      \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS
# 0                                                NaN                             \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  Gini index (World Bank estimate) - SI.POV.GINI
# 0  ...                                             NaN  \
# 1  ...                                             NaN
# 2  ...                                             NaN
# 3  ...                                             NaN
# 4  ...                                             NaN
#
#    Income Classification (World Bank Definition)
# 0                                    High income  \
# 1                                    High income
# 2                                    High income
# 3                                    High income
# 4                                    High income
#
#    Individuals using the Internet (% of population) - IT.NET.USER.ZS
# 0                                                NaN                  \
# 1                                               17.1
# 2                                               18.8
# 3                                               20.8
# 4                                               23.0
#
#    Life expectancy at birth, total (years) - SP.DYN.LE00.IN
# 0                                                NaN         \
# 1                                             73.853
# 2                                             73.937
# 3                                             74.038
# 4                                             74.156
#
#    Population, total - SP.POP.TOTL  Regime Type (RoW Measure Definition)
# 0                              NaN                                   NaN  \
# 1                          92892.0                                   NaN
# 2                          94992.0                                   NaN
# 3                          97016.0                                   NaN
# 4                          98744.0                                   NaN
#
#    Rural population (% of total population) - SP.RUR.TOTL.ZS
# 0                                             53.283          \
# 1                                             53.661
# 2                                             54.028
# 3                                             54.394
# 4                                             54.760
#
#    Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS
# 0                                                NaN             \
# 1                                           0.000712
# 2                                           0.000657
# 3                                           0.000700
# 4                                           0.000685
#
#    Urban population (% of total population) - SP.URB.TOTL.IN.ZS
# 0                                                NaN             \
# 1                                             46.339
# 2                                             45.972
# 3                                             45.606
# 4                                             45.240
#
#    World Regions (UN SDG Definition)
# 0        Latin America and Caribbean
# 1        Latin America and Caribbean
# 2        Latin America and Caribbean
# 3        Latin America and Caribbean
# 4        Latin America and Caribbean
#
# [5 rows x 54 columns]
#   Country Name  Year
# 0        Aruba  2000  \
# 1        Aruba  2001
# 2        Aruba  2002
# 3        Aruba  2003
# 4        Aruba  2004
#
#    Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS
# 0                                          70.792132          \
# 1                                          74.338086
# 2                                          77.553957
# 3                                          78.551686
# 4                                          74.705440
#
#    Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS
# 0                                             0.1753                                    \
# 1                                             0.1805
# 2                                             0.1814
# 3                                             0.1846
# 4                                             0.1871
#
#    Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes
# 0                                              2.378                                      \
# 1                                              2.407
# 2                                              2.437
# 3                                              2.561
# 4                                              2.616
#
#        Continent Income Classification (World Bank Definition)
# 0  North America                                   High income
# 1  North America                                   High income
# 2  North America                                   High income
# 3  North America                                   High income
# 4  North America                                   High income
#   Country Name  Year  Final Consumption  Renewable Energy Consumption
# 0        Aruba  2000          70.792132                        0.1753  \
# 1        Aruba  2001          74.338086                        0.1805
# 2        Aruba  2002          77.553957                        0.1814
# 3        Aruba  2003          78.551686                        0.1846
# 4        Aruba  2004          74.705440                        0.1871
#
#    Annual CO2 Emissions      Continent Income Classification
# 0                 2.378  North America           High income
# 1                 2.407  North America           High income
# 2                 2.437  North America           High income
# 3                 2.561  North America           High income
# 4                 2.616  North America           High income
#        Continent Country Name Income Classification  Year
# 0  North America        Aruba           High income  2000  \
# 1  North America        Aruba           High income  2001
# 2  North America        Aruba           High income  2002
# 3  North America        Aruba           High income  2003
# 4  North America        Aruba           High income  2004
#
#    Annual CO2 Emissions  Renewable Energy Consumption  Final Consumption
# 0                 2.378                        0.1753          70.792132
# 1                 2.407                        0.1805          74.338086
# 2                 2.437                        0.1814          77.553957
# 3                 2.561                        0.1846          78.551686
# 4                 2.616                        0.1871          74.705440
# Continent                         2
# Country Name                      0
# Income Classification             2
# Year                              0
# Annual CO2 Emissions              2
# Renewable Energy Consumption      0
# Final Consumption               240
# dtype: int64
#               Year  Annual CO2 Emissions  Renewable Energy Consumption
# count  3287.000000           3285.000000                   3287.000000  \
# mean   2009.000000            174.646907                     32.672923
# std       5.478059            757.653194                     29.921274
# min    2000.000000              0.048000                      0.000000
# 25%    2004.000000              2.426000                      6.835400
# 50%    2009.000000             12.621000                     22.659800
# 75%    2014.000000             72.012000                     54.638100
# max    2018.000000           9956.569000                     98.342903
#
#        Final Consumption
# count        3047.000000
# mean           80.410827
# std            19.334168
# min            16.712957
# 25%            71.261800
# 50%            79.509708
# 75%            89.748636
# max           241.973940
# (3287, 7)
# Continent
# Africa           61.446756
# Asia             21.308767
# Europe           18.771750
# North America    23.068256
# Oceania          28.269439
# South America    29.872472
# Name: Renewable Energy Consumption, dtype: float64

# %%
"""World Sustainability Dataset"""
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# read csv and assign it to variable df
df = pd.read_csv(
    "/workspaces/Data-Analysis-with-Python/Project/WorldSustainabilityDataset.csv"
)
print(df.head())

# only keep country name, year, final consumption expenditure, renewable energy consumption,
# annual CO2 emissions, continent, and income classification
df = df[
    [
        "Country Name",
        "Year",
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes",
        "Continent",
        "Income Classification (World Bank Definition)",
    ]
]

print(df.head())

# rename columns
df.rename(
    columns={
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS": "Final Consumption",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS": "Renewable Energy Consumption",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes": "Annual CO2 Emissions",
        "Income Classification (World Bank Definition)": "Income Classification",
    },
    inplace=True,
)

print(df.head())

# rearrange columns
df = df[
    [
        "Continent",
        "Country Name",
        "Income Classification",
        "Year",
        "Annual CO2 Emissions",
        "Renewable Energy Consumption",
        "Final Consumption",
    ]
]

print(df.head())

# check to see how many null objects are in the dataset
print(df.isnull().sum())

# quick summary of each column in the dataframe
print(df.describe())

# data dimensions
print(df.shape)

# calculate mean of renewable energy consumption grouped by continent and year
print(df.groupby(["Continent", "Year")["Renewable Energy Consumption"].mean())
# Out:
#   Cell In[4], line 68
#     print(df.groupby(["Continent", "Year")["Renewable Energy Consumption"].mean())
#                                          ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
"""World Sustainability Dataset"""
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# read csv and assign it to variable df
df = pd.read_csv(
    "/workspaces/Data-Analysis-with-Python/Project/WorldSustainabilityDataset.csv"
)
print(df.head())

# only keep country name, year, final consumption expenditure, renewable energy consumption,
# annual CO2 emissions, continent, and income classification
df = df[
    [
        "Country Name",
        "Year",
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes",
        "Continent",
        "Income Classification (World Bank Definition)",
    ]
]

print(df.head())

# rename columns
df.rename(
    columns={
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS": "Final Consumption",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS": "Renewable Energy Consumption",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes": "Annual CO2 Emissions",
        "Income Classification (World Bank Definition)": "Income Classification",
    },
    inplace=True,
)

print(df.head())

# rearrange columns
df = df[
    [
        "Continent",
        "Country Name",
        "Income Classification",
        "Year",
        "Annual CO2 Emissions",
        "Renewable Energy Consumption",
        "Final Consumption",
    ]
]

print(df.head())

# check to see how many null objects are in the dataset
print(df.isnull().sum())

# quick summary of each column in the dataframe
print(df.describe())

# data dimensions
print(df.shape)

# calculate mean of renewable energy consumption grouped by continent and year
print(df.groupby(["Continent", "Year"])["Renewable Energy Consumption"].mean())
# Out:
#   Country Name Country Code  Year
# 0        Aruba          ABW  2000  \
# 1        Aruba          ABW  2001
# 2        Aruba          ABW  2002
# 3        Aruba          ABW  2003
# 4        Aruba          ABW  2004
#
#    Access to electricity (% of population) - EG.ELC.ACCS.ZS
# 0                                          91.660398         \
# 1                                         100.000000
# 2                                         100.000000
# 3                                         100.000000
# 4                                         100.000000
#
#    Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS
# 0                                          15.392211                                           \
# 1                                          11.491930
# 2                                           3.893620
# 3                                           6.713863
# 4                                           9.801576
#
#    Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS
# 0                                           2.389134                       \
# 1                                           2.509046
# 2                                           2.721385
# 3                                           2.733676
# 4                                           2.678363
#
#    Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS
# 0                                           0.000190                             \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS
# 0                                           0.000190                      \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS
# 0                                                NaN                             \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  Gini index (World Bank estimate) - SI.POV.GINI
# 0  ...                                             NaN  \
# 1  ...                                             NaN
# 2  ...                                             NaN
# 3  ...                                             NaN
# 4  ...                                             NaN
#
#    Income Classification (World Bank Definition)
# 0                                    High income  \
# 1                                    High income
# 2                                    High income
# 3                                    High income
# 4                                    High income
#
#    Individuals using the Internet (% of population) - IT.NET.USER.ZS
# 0                                                NaN                  \
# 1                                               17.1
# 2                                               18.8
# 3                                               20.8
# 4                                               23.0
#
#    Life expectancy at birth, total (years) - SP.DYN.LE00.IN
# 0                                                NaN         \
# 1                                             73.853
# 2                                             73.937
# 3                                             74.038
# 4                                             74.156
#
#    Population, total - SP.POP.TOTL  Regime Type (RoW Measure Definition)
# 0                              NaN                                   NaN  \
# 1                          92892.0                                   NaN
# 2                          94992.0                                   NaN
# 3                          97016.0                                   NaN
# 4                          98744.0                                   NaN
#
#    Rural population (% of total population) - SP.RUR.TOTL.ZS
# 0                                             53.283          \
# 1                                             53.661
# 2                                             54.028
# 3                                             54.394
# 4                                             54.760
#
#    Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS
# 0                                                NaN             \
# 1                                           0.000712
# 2                                           0.000657
# 3                                           0.000700
# 4                                           0.000685
#
#    Urban population (% of total population) - SP.URB.TOTL.IN.ZS
# 0                                                NaN             \
# 1                                             46.339
# 2                                             45.972
# 3                                             45.606
# 4                                             45.240
#
#    World Regions (UN SDG Definition)
# 0        Latin America and Caribbean
# 1        Latin America and Caribbean
# 2        Latin America and Caribbean
# 3        Latin America and Caribbean
# 4        Latin America and Caribbean
#
# [5 rows x 54 columns]
#   Country Name  Year
# 0        Aruba  2000  \
# 1        Aruba  2001
# 2        Aruba  2002
# 3        Aruba  2003
# 4        Aruba  2004
#
#    Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS
# 0                                          70.792132          \
# 1                                          74.338086
# 2                                          77.553957
# 3                                          78.551686
# 4                                          74.705440
#
#    Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS
# 0                                             0.1753                                    \
# 1                                             0.1805
# 2                                             0.1814
# 3                                             0.1846
# 4                                             0.1871
#
#    Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes
# 0                                              2.378                                      \
# 1                                              2.407
# 2                                              2.437
# 3                                              2.561
# 4                                              2.616
#
#        Continent Income Classification (World Bank Definition)
# 0  North America                                   High income
# 1  North America                                   High income
# 2  North America                                   High income
# 3  North America                                   High income
# 4  North America                                   High income
#   Country Name  Year  Final Consumption  Renewable Energy Consumption
# 0        Aruba  2000          70.792132                        0.1753  \
# 1        Aruba  2001          74.338086                        0.1805
# 2        Aruba  2002          77.553957                        0.1814
# 3        Aruba  2003          78.551686                        0.1846
# 4        Aruba  2004          74.705440                        0.1871
#
#    Annual CO2 Emissions      Continent Income Classification
# 0                 2.378  North America           High income
# 1                 2.407  North America           High income
# 2                 2.437  North America           High income
# 3                 2.561  North America           High income
# 4                 2.616  North America           High income
#        Continent Country Name Income Classification  Year
# 0  North America        Aruba           High income  2000  \
# 1  North America        Aruba           High income  2001
# 2  North America        Aruba           High income  2002
# 3  North America        Aruba           High income  2003
# 4  North America        Aruba           High income  2004
#
#    Annual CO2 Emissions  Renewable Energy Consumption  Final Consumption
# 0                 2.378                        0.1753          70.792132
# 1                 2.407                        0.1805          74.338086
# 2                 2.437                        0.1814          77.553957
# 3                 2.561                        0.1846          78.551686
# 4                 2.616                        0.1871          74.705440
# Continent                         2
# Country Name                      0
# Income Classification             2
# Year                              0
# Annual CO2 Emissions              2
# Renewable Energy Consumption      0
# Final Consumption               240
# dtype: int64
#               Year  Annual CO2 Emissions  Renewable Energy Consumption
# count  3287.000000           3285.000000                   3287.000000  \
# mean   2009.000000            174.646907                     32.672923
# std       5.478059            757.653194                     29.921274
# min    2000.000000              0.048000                      0.000000
# 25%    2004.000000              2.426000                      6.835400
# 50%    2009.000000             12.621000                     22.659800
# 75%    2014.000000             72.012000                     54.638100
# max    2018.000000           9956.569000                     98.342903
#
#        Final Consumption
# count        3047.000000
# mean           80.410827
# std            19.334168
# min            16.712957
# 25%            71.261800
# 50%            79.509708
# 75%            89.748636
# max           241.973940
# (3287, 7)
# Continent      Year
# Africa         2000    65.081958
#                2001    64.630059
#                2002    64.341547
#                2003    63.780913
#                2004    63.205947
#                          ...
# South America  2014    27.546450
#                2015    27.524333
#                2016    27.912391
#                2017    28.361892
#                2018    28.009266
# Name: Renewable Energy Consumption, Length: 114, dtype: float64

# %%
"""World Sustainability Dataset"""
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# read csv and assign it to variable df
df = pd.read_csv(
    "/workspaces/Data-Analysis-with-Python/Project/WorldSustainabilityDataset.csv"
)
print(df.head())

# only keep country name, year, final consumption expenditure, renewable energy consumption,
# annual CO2 emissions, continent, and income classification
df = df[
    [
        "Country Name",
        "Year",
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes",
        "Continent",
        "Income Classification (World Bank Definition)",
    ]
]

print(df.head())

# rename columns
df.rename(
    columns={
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS": "Final Consumption",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS": "Renewable Energy Consumption",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes": "Annual CO2 Emissions",
        "Income Classification (World Bank Definition)": "Income Classification",
    },
    inplace=True,
)

print(df.head())

# rearrange columns
df = df[
    [
        "Continent",
        "Country Name",
        "Income Classification",
        "Year",
        "Annual CO2 Emissions",
        "Renewable Energy Consumption",
        "Final Consumption",
    ]
]

print(df.head())

# check to see how many null objects are in the dataset
print(df.isnull().sum())

# quick summary of each column in the dataframe
print(df.describe())

# data dimensions
print(df.shape)

# calculate mean of renewable energy consumption grouped by continent and year
print(df.groupby(["Continent", "Year"])["Renewable Energy Consumption"].mean())

# plot a graph
df.set_index("Year", inplace=True)
df.groupby(["Continent", "Year"])["Renewable Energy Consumption"].mean().plot(legend=True)
# Out:
#   Country Name Country Code  Year
# 0        Aruba          ABW  2000  \
# 1        Aruba          ABW  2001
# 2        Aruba          ABW  2002
# 3        Aruba          ABW  2003
# 4        Aruba          ABW  2004
#
#    Access to electricity (% of population) - EG.ELC.ACCS.ZS
# 0                                          91.660398         \
# 1                                         100.000000
# 2                                         100.000000
# 3                                         100.000000
# 4                                         100.000000
#
#    Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS
# 0                                          15.392211                                           \
# 1                                          11.491930
# 2                                           3.893620
# 3                                           6.713863
# 4                                           9.801576
#
#    Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS
# 0                                           2.389134                       \
# 1                                           2.509046
# 2                                           2.721385
# 3                                           2.733676
# 4                                           2.678363
#
#    Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS
# 0                                           0.000190                             \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS
# 0                                           0.000190                      \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS
# 0                                                NaN                             \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  Gini index (World Bank estimate) - SI.POV.GINI
# 0  ...                                             NaN  \
# 1  ...                                             NaN
# 2  ...                                             NaN
# 3  ...                                             NaN
# 4  ...                                             NaN
#
#    Income Classification (World Bank Definition)
# 0                                    High income  \
# 1                                    High income
# 2                                    High income
# 3                                    High income
# 4                                    High income
#
#    Individuals using the Internet (% of population) - IT.NET.USER.ZS
# 0                                                NaN                  \
# 1                                               17.1
# 2                                               18.8
# 3                                               20.8
# 4                                               23.0
#
#    Life expectancy at birth, total (years) - SP.DYN.LE00.IN
# 0                                                NaN         \
# 1                                             73.853
# 2                                             73.937
# 3                                             74.038
# 4                                             74.156
#
#    Population, total - SP.POP.TOTL  Regime Type (RoW Measure Definition)
# 0                              NaN                                   NaN  \
# 1                          92892.0                                   NaN
# 2                          94992.0                                   NaN
# 3                          97016.0                                   NaN
# 4                          98744.0                                   NaN
#
#    Rural population (% of total population) - SP.RUR.TOTL.ZS
# 0                                             53.283          \
# 1                                             53.661
# 2                                             54.028
# 3                                             54.394
# 4                                             54.760
#
#    Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS
# 0                                                NaN             \
# 1                                           0.000712
# 2                                           0.000657
# 3                                           0.000700
# 4                                           0.000685
#
#    Urban population (% of total population) - SP.URB.TOTL.IN.ZS
# 0                                                NaN             \
# 1                                             46.339
# 2                                             45.972
# 3                                             45.606
# 4                                             45.240
#
#    World Regions (UN SDG Definition)
# 0        Latin America and Caribbean
# 1        Latin America and Caribbean
# 2        Latin America and Caribbean
# 3        Latin America and Caribbean
# 4        Latin America and Caribbean
#
# [5 rows x 54 columns]
#   Country Name  Year
# 0        Aruba  2000  \
# 1        Aruba  2001
# 2        Aruba  2002
# 3        Aruba  2003
# 4        Aruba  2004
#
#    Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS
# 0                                          70.792132          \
# 1                                          74.338086
# 2                                          77.553957
# 3                                          78.551686
# 4                                          74.705440
#
#    Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS
# 0                                             0.1753                                    \
# 1                                             0.1805
# 2                                             0.1814
# 3                                             0.1846
# 4                                             0.1871
#
#    Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes
# 0                                              2.378                                      \
# 1                                              2.407
# 2                                              2.437
# 3                                              2.561
# 4                                              2.616
#
#        Continent Income Classification (World Bank Definition)
# 0  North America                                   High income
# 1  North America                                   High income
# 2  North America                                   High income
# 3  North America                                   High income
# 4  North America                                   High income
#   Country Name  Year  Final Consumption  Renewable Energy Consumption
# 0        Aruba  2000          70.792132                        0.1753  \
# 1        Aruba  2001          74.338086                        0.1805
# 2        Aruba  2002          77.553957                        0.1814
# 3        Aruba  2003          78.551686                        0.1846
# 4        Aruba  2004          74.705440                        0.1871
#
#    Annual CO2 Emissions      Continent Income Classification
# 0                 2.378  North America           High income
# 1                 2.407  North America           High income
# 2                 2.437  North America           High income
# 3                 2.561  North America           High income
# 4                 2.616  North America           High income
#        Continent Country Name Income Classification  Year
# 0  North America        Aruba           High income  2000  \
# 1  North America        Aruba           High income  2001
# 2  North America        Aruba           High income  2002
# 3  North America        Aruba           High income  2003
# 4  North America        Aruba           High income  2004
#
#    Annual CO2 Emissions  Renewable Energy Consumption  Final Consumption
# 0                 2.378                        0.1753          70.792132
# 1                 2.407                        0.1805          74.338086
# 2                 2.437                        0.1814          77.553957
# 3                 2.561                        0.1846          78.551686
# 4                 2.616                        0.1871          74.705440
# Continent                         2
# Country Name                      0
# Income Classification             2
# Year                              0
# Annual CO2 Emissions              2
# Renewable Energy Consumption      0
# Final Consumption               240
# dtype: int64
#               Year  Annual CO2 Emissions  Renewable Energy Consumption
# count  3287.000000           3285.000000                   3287.000000  \
# mean   2009.000000            174.646907                     32.672923
# std       5.478059            757.653194                     29.921274
# min    2000.000000              0.048000                      0.000000
# 25%    2004.000000              2.426000                      6.835400
# 50%    2009.000000             12.621000                     22.659800
# 75%    2014.000000             72.012000                     54.638100
# max    2018.000000           9956.569000                     98.342903
#
#        Final Consumption
# count        3047.000000
# mean           80.410827
# std            19.334168
# min            16.712957
# 25%            71.261800
# 50%            79.509708
# 75%            89.748636
# max           241.973940
# (3287, 7)
# Continent      Year
# Africa         2000    65.081958
#                2001    64.630059
#                2002    64.341547
#                2003    63.780913
#                2004    63.205947
#                          ...
# South America  2014    27.546450
#                2015    27.524333
#                2016    27.912391
#                2017    28.361892
#                2018    28.009266
# Name: Renewable Energy Consumption, Length: 114, dtype: float64
# <Axes: xlabel='Continent,Year'>

# %%
"""World Sustainability Dataset"""
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# read csv and assign it to variable df
df = pd.read_csv(
    "/workspaces/Data-Analysis-with-Python/Project/WorldSustainabilityDataset.csv"
)
print(df.head())

# only keep country name, year, final consumption expenditure, renewable energy consumption,
# annual CO2 emissions, continent, and income classification
df = df[
    [
        "Country Name",
        "Year",
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes",
        "Continent",
        "Income Classification (World Bank Definition)",
    ]
]

print(df.head())

# rename columns
df.rename(
    columns={
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS": "Final Consumption",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS": "Renewable Energy Consumption",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes": "Annual CO2 Emissions",
        "Income Classification (World Bank Definition)": "Income Classification",
    },
    inplace=True,
)

print(df.head())

# rearrange columns
df = df[
    [
        "Continent",
        "Country Name",
        "Income Classification",
        "Year",
        "Annual CO2 Emissions",
        "Renewable Energy Consumption",
        "Final Consumption",
    ]
]

print(df.head())

# check to see how many null objects are in the dataset
print(df.isnull().sum())

# quick summary of each column in the dataframe
print(df.describe())

# data dimensions
print(df.shape)

# calculate mean of renewable energy consumption grouped by continent and year
print(df.groupby(["Continent", "Year"])["Renewable Energy Consumption"].mean())

# plot a graph
df.set_index("Year", inplace=True)
df.groupby("Continent")["Renewable Energy Consumption"].mean().plot(legend=True)
# Out:
#   Country Name Country Code  Year
# 0        Aruba          ABW  2000  \
# 1        Aruba          ABW  2001
# 2        Aruba          ABW  2002
# 3        Aruba          ABW  2003
# 4        Aruba          ABW  2004
#
#    Access to electricity (% of population) - EG.ELC.ACCS.ZS
# 0                                          91.660398         \
# 1                                         100.000000
# 2                                         100.000000
# 3                                         100.000000
# 4                                         100.000000
#
#    Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS
# 0                                          15.392211                                           \
# 1                                          11.491930
# 2                                           3.893620
# 3                                           6.713863
# 4                                           9.801576
#
#    Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS
# 0                                           2.389134                       \
# 1                                           2.509046
# 2                                           2.721385
# 3                                           2.733676
# 4                                           2.678363
#
#    Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS
# 0                                           0.000190                             \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS
# 0                                           0.000190                      \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS
# 0                                                NaN                             \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  Gini index (World Bank estimate) - SI.POV.GINI
# 0  ...                                             NaN  \
# 1  ...                                             NaN
# 2  ...                                             NaN
# 3  ...                                             NaN
# 4  ...                                             NaN
#
#    Income Classification (World Bank Definition)
# 0                                    High income  \
# 1                                    High income
# 2                                    High income
# 3                                    High income
# 4                                    High income
#
#    Individuals using the Internet (% of population) - IT.NET.USER.ZS
# 0                                                NaN                  \
# 1                                               17.1
# 2                                               18.8
# 3                                               20.8
# 4                                               23.0
#
#    Life expectancy at birth, total (years) - SP.DYN.LE00.IN
# 0                                                NaN         \
# 1                                             73.853
# 2                                             73.937
# 3                                             74.038
# 4                                             74.156
#
#    Population, total - SP.POP.TOTL  Regime Type (RoW Measure Definition)
# 0                              NaN                                   NaN  \
# 1                          92892.0                                   NaN
# 2                          94992.0                                   NaN
# 3                          97016.0                                   NaN
# 4                          98744.0                                   NaN
#
#    Rural population (% of total population) - SP.RUR.TOTL.ZS
# 0                                             53.283          \
# 1                                             53.661
# 2                                             54.028
# 3                                             54.394
# 4                                             54.760
#
#    Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS
# 0                                                NaN             \
# 1                                           0.000712
# 2                                           0.000657
# 3                                           0.000700
# 4                                           0.000685
#
#    Urban population (% of total population) - SP.URB.TOTL.IN.ZS
# 0                                                NaN             \
# 1                                             46.339
# 2                                             45.972
# 3                                             45.606
# 4                                             45.240
#
#    World Regions (UN SDG Definition)
# 0        Latin America and Caribbean
# 1        Latin America and Caribbean
# 2        Latin America and Caribbean
# 3        Latin America and Caribbean
# 4        Latin America and Caribbean
#
# [5 rows x 54 columns]
#   Country Name  Year
# 0        Aruba  2000  \
# 1        Aruba  2001
# 2        Aruba  2002
# 3        Aruba  2003
# 4        Aruba  2004
#
#    Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS
# 0                                          70.792132          \
# 1                                          74.338086
# 2                                          77.553957
# 3                                          78.551686
# 4                                          74.705440
#
#    Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS
# 0                                             0.1753                                    \
# 1                                             0.1805
# 2                                             0.1814
# 3                                             0.1846
# 4                                             0.1871
#
#    Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes
# 0                                              2.378                                      \
# 1                                              2.407
# 2                                              2.437
# 3                                              2.561
# 4                                              2.616
#
#        Continent Income Classification (World Bank Definition)
# 0  North America                                   High income
# 1  North America                                   High income
# 2  North America                                   High income
# 3  North America                                   High income
# 4  North America                                   High income
#   Country Name  Year  Final Consumption  Renewable Energy Consumption
# 0        Aruba  2000          70.792132                        0.1753  \
# 1        Aruba  2001          74.338086                        0.1805
# 2        Aruba  2002          77.553957                        0.1814
# 3        Aruba  2003          78.551686                        0.1846
# 4        Aruba  2004          74.705440                        0.1871
#
#    Annual CO2 Emissions      Continent Income Classification
# 0                 2.378  North America           High income
# 1                 2.407  North America           High income
# 2                 2.437  North America           High income
# 3                 2.561  North America           High income
# 4                 2.616  North America           High income
#        Continent Country Name Income Classification  Year
# 0  North America        Aruba           High income  2000  \
# 1  North America        Aruba           High income  2001
# 2  North America        Aruba           High income  2002
# 3  North America        Aruba           High income  2003
# 4  North America        Aruba           High income  2004
#
#    Annual CO2 Emissions  Renewable Energy Consumption  Final Consumption
# 0                 2.378                        0.1753          70.792132
# 1                 2.407                        0.1805          74.338086
# 2                 2.437                        0.1814          77.553957
# 3                 2.561                        0.1846          78.551686
# 4                 2.616                        0.1871          74.705440
# Continent                         2
# Country Name                      0
# Income Classification             2
# Year                              0
# Annual CO2 Emissions              2
# Renewable Energy Consumption      0
# Final Consumption               240
# dtype: int64
#               Year  Annual CO2 Emissions  Renewable Energy Consumption
# count  3287.000000           3285.000000                   3287.000000  \
# mean   2009.000000            174.646907                     32.672923
# std       5.478059            757.653194                     29.921274
# min    2000.000000              0.048000                      0.000000
# 25%    2004.000000              2.426000                      6.835400
# 50%    2009.000000             12.621000                     22.659800
# 75%    2014.000000             72.012000                     54.638100
# max    2018.000000           9956.569000                     98.342903
#
#        Final Consumption
# count        3047.000000
# mean           80.410827
# std            19.334168
# min            16.712957
# 25%            71.261800
# 50%            79.509708
# 75%            89.748636
# max           241.973940
# (3287, 7)
# Continent      Year
# Africa         2000    65.081958
#                2001    64.630059
#                2002    64.341547
#                2003    63.780913
#                2004    63.205947
#                          ...
# South America  2014    27.546450
#                2015    27.524333
#                2016    27.912391
#                2017    28.361892
#                2018    28.009266
# Name: Renewable Energy Consumption, Length: 114, dtype: float64
# <Axes: xlabel='Continent'>

# %%
"""World Sustainability Dataset"""
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# read csv and assign it to variable df
df = pd.read_csv(
    "/workspaces/Data-Analysis-with-Python/Project/WorldSustainabilityDataset.csv"
)
print(df.head())

# only keep country name, year, final consumption expenditure, renewable energy consumption,
# annual CO2 emissions, continent, and income classification
df = df[
    [
        "Country Name",
        "Year",
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes",
        "Continent",
        "Income Classification (World Bank Definition)",
    ]
]

print(df.head())

# rename columns
df.rename(
    columns={
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS": "Final Consumption",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS": "Renewable Energy Consumption",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes": "Annual CO2 Emissions",
        "Income Classification (World Bank Definition)": "Income Classification",
    },
    inplace=True,
)

print(df.head())

# rearrange columns
df = df[
    [
        "Continent",
        "Country Name",
        "Income Classification",
        "Year",
        "Annual CO2 Emissions",
        "Renewable Energy Consumption",
        "Final Consumption",
    ]
]

print(df.head())

# check to see how many null objects are in the dataset
print(df.isnull().sum())

# quick summary of each column in the dataframe
print(df.describe())

# data dimensions
print(df.shape)

# calculate mean of renewable energy consumption grouped by continent and year
rec_df = df.groupby(["Continent", "Year"])["Renewable Energy Consumption"].mean())

# plot a graph
rec_df.plot()
plt.show()
# Out:
#   Cell In[8], line 68
#     rec_df = df.groupby(["Continent", "Year"])["Renewable Energy Consumption"].mean())
#                                                                                      ^
# SyntaxError: unmatched ')'

# %%
"""World Sustainability Dataset"""
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# read csv and assign it to variable df
df = pd.read_csv(
    "/workspaces/Data-Analysis-with-Python/Project/WorldSustainabilityDataset.csv"
)
print(df.head())

# only keep country name, year, final consumption expenditure, renewable energy consumption,
# annual CO2 emissions, continent, and income classification
df = df[
    [
        "Country Name",
        "Year",
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes",
        "Continent",
        "Income Classification (World Bank Definition)",
    ]
]

print(df.head())

# rename columns
df.rename(
    columns={
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS": "Final Consumption",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS": "Renewable Energy Consumption",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes": "Annual CO2 Emissions",
        "Income Classification (World Bank Definition)": "Income Classification",
    },
    inplace=True,
)

print(df.head())

# rearrange columns
df = df[
    [
        "Continent",
        "Country Name",
        "Income Classification",
        "Year",
        "Annual CO2 Emissions",
        "Renewable Energy Consumption",
        "Final Consumption",
    ]
]

print(df.head())

# check to see how many null objects are in the dataset
print(df.isnull().sum())

# quick summary of each column in the dataframe
print(df.describe())

# data dimensions
print(df.shape)

# calculate mean of renewable energy consumption grouped by continent and year
rec_df = df.groupby(["Continent", "Year"])["Renewable Energy Consumption"].mean()

# plot a graph
rec_df.plot()
plt.show()
# Out:
#   Country Name Country Code  Year
# 0        Aruba          ABW  2000  \
# 1        Aruba          ABW  2001
# 2        Aruba          ABW  2002
# 3        Aruba          ABW  2003
# 4        Aruba          ABW  2004
#
#    Access to electricity (% of population) - EG.ELC.ACCS.ZS
# 0                                          91.660398         \
# 1                                         100.000000
# 2                                         100.000000
# 3                                         100.000000
# 4                                         100.000000
#
#    Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS
# 0                                          15.392211                                           \
# 1                                          11.491930
# 2                                           3.893620
# 3                                           6.713863
# 4                                           9.801576
#
#    Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS
# 0                                           2.389134                       \
# 1                                           2.509046
# 2                                           2.721385
# 3                                           2.733676
# 4                                           2.678363
#
#    Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS
# 0                                           0.000190                             \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS
# 0                                           0.000190                      \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS
# 0                                                NaN                             \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  Gini index (World Bank estimate) - SI.POV.GINI
# 0  ...                                             NaN  \
# 1  ...                                             NaN
# 2  ...                                             NaN
# 3  ...                                             NaN
# 4  ...                                             NaN
#
#    Income Classification (World Bank Definition)
# 0                                    High income  \
# 1                                    High income
# 2                                    High income
# 3                                    High income
# 4                                    High income
#
#    Individuals using the Internet (% of population) - IT.NET.USER.ZS
# 0                                                NaN                  \
# 1                                               17.1
# 2                                               18.8
# 3                                               20.8
# 4                                               23.0
#
#    Life expectancy at birth, total (years) - SP.DYN.LE00.IN
# 0                                                NaN         \
# 1                                             73.853
# 2                                             73.937
# 3                                             74.038
# 4                                             74.156
#
#    Population, total - SP.POP.TOTL  Regime Type (RoW Measure Definition)
# 0                              NaN                                   NaN  \
# 1                          92892.0                                   NaN
# 2                          94992.0                                   NaN
# 3                          97016.0                                   NaN
# 4                          98744.0                                   NaN
#
#    Rural population (% of total population) - SP.RUR.TOTL.ZS
# 0                                             53.283          \
# 1                                             53.661
# 2                                             54.028
# 3                                             54.394
# 4                                             54.760
#
#    Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS
# 0                                                NaN             \
# 1                                           0.000712
# 2                                           0.000657
# 3                                           0.000700
# 4                                           0.000685
#
#    Urban population (% of total population) - SP.URB.TOTL.IN.ZS
# 0                                                NaN             \
# 1                                             46.339
# 2                                             45.972
# 3                                             45.606
# 4                                             45.240
#
#    World Regions (UN SDG Definition)
# 0        Latin America and Caribbean
# 1        Latin America and Caribbean
# 2        Latin America and Caribbean
# 3        Latin America and Caribbean
# 4        Latin America and Caribbean
#
# [5 rows x 54 columns]
#   Country Name  Year
# 0        Aruba  2000  \
# 1        Aruba  2001
# 2        Aruba  2002
# 3        Aruba  2003
# 4        Aruba  2004
#
#    Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS
# 0                                          70.792132          \
# 1                                          74.338086
# 2                                          77.553957
# 3                                          78.551686
# 4                                          74.705440
#
#    Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS
# 0                                             0.1753                                    \
# 1                                             0.1805
# 2                                             0.1814
# 3                                             0.1846
# 4                                             0.1871
#
#    Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes
# 0                                              2.378                                      \
# 1                                              2.407
# 2                                              2.437
# 3                                              2.561
# 4                                              2.616
#
#        Continent Income Classification (World Bank Definition)
# 0  North America                                   High income
# 1  North America                                   High income
# 2  North America                                   High income
# 3  North America                                   High income
# 4  North America                                   High income
#   Country Name  Year  Final Consumption  Renewable Energy Consumption
# 0        Aruba  2000          70.792132                        0.1753  \
# 1        Aruba  2001          74.338086                        0.1805
# 2        Aruba  2002          77.553957                        0.1814
# 3        Aruba  2003          78.551686                        0.1846
# 4        Aruba  2004          74.705440                        0.1871
#
#    Annual CO2 Emissions      Continent Income Classification
# 0                 2.378  North America           High income
# 1                 2.407  North America           High income
# 2                 2.437  North America           High income
# 3                 2.561  North America           High income
# 4                 2.616  North America           High income
#        Continent Country Name Income Classification  Year
# 0  North America        Aruba           High income  2000  \
# 1  North America        Aruba           High income  2001
# 2  North America        Aruba           High income  2002
# 3  North America        Aruba           High income  2003
# 4  North America        Aruba           High income  2004
#
#    Annual CO2 Emissions  Renewable Energy Consumption  Final Consumption
# 0                 2.378                        0.1753          70.792132
# 1                 2.407                        0.1805          74.338086
# 2                 2.437                        0.1814          77.553957
# 3                 2.561                        0.1846          78.551686
# 4                 2.616                        0.1871          74.705440
# Continent                         2
# Country Name                      0
# Income Classification             2
# Year                              0
# Annual CO2 Emissions              2
# Renewable Energy Consumption      0
# Final Consumption               240
# dtype: int64
#               Year  Annual CO2 Emissions  Renewable Energy Consumption
# count  3287.000000           3285.000000                   3287.000000  \
# mean   2009.000000            174.646907                     32.672923
# std       5.478059            757.653194                     29.921274
# min    2000.000000              0.048000                      0.000000
# 25%    2004.000000              2.426000                      6.835400
# 50%    2009.000000             12.621000                     22.659800
# 75%    2014.000000             72.012000                     54.638100
# max    2018.000000           9956.569000                     98.342903
#
#        Final Consumption
# count        3047.000000
# mean           80.410827
# std            19.334168
# min            16.712957
# 25%            71.261800
# 50%            79.509708
# 75%            89.748636
# max           241.973940
# (3287, 7)

# %%
"""World Sustainability Dataset"""
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# read csv and assign it to variable df
df = pd.read_csv(
    "/workspaces/Data-Analysis-with-Python/Project/WorldSustainabilityDataset.csv"
)
print(df.head())

# only keep country name, year, final consumption expenditure, renewable energy consumption,
# annual CO2 emissions, continent, and income classification
df = df[
    [
        "Country Name",
        "Year",
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes",
        "Continent",
        "Income Classification (World Bank Definition)",
    ]
]

print(df.head())

# rename columns
df.rename(
    columns={
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS": "Final Consumption",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS": "Renewable Energy Consumption",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes": "Annual CO2 Emissions",
        "Income Classification (World Bank Definition)": "Income Classification",
    },
    inplace=True,
)

print(df.head())

# rearrange columns
df = df[
    [
        "Continent",
        "Country Name",
        "Income Classification",
        "Year",
        "Annual CO2 Emissions",
        "Renewable Energy Consumption",
        "Final Consumption",
    ]
]

print(df.head())

# check to see how many null objects are in the dataset
print(df.isnull().sum())

# quick summary of each column in the dataframe
print(df.describe())

# data dimensions
print(df.shape)

# calculate mean of renewable energy consumption grouped by continent and year
print(df.groupby(["Continent", "Year"])["Renewable Energy Consumption"].mean())
# Out:
#   Country Name Country Code  Year
# 0        Aruba          ABW  2000  \
# 1        Aruba          ABW  2001
# 2        Aruba          ABW  2002
# 3        Aruba          ABW  2003
# 4        Aruba          ABW  2004
#
#    Access to electricity (% of population) - EG.ELC.ACCS.ZS
# 0                                          91.660398         \
# 1                                         100.000000
# 2                                         100.000000
# 3                                         100.000000
# 4                                         100.000000
#
#    Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS
# 0                                          15.392211                                           \
# 1                                          11.491930
# 2                                           3.893620
# 3                                           6.713863
# 4                                           9.801576
#
#    Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS
# 0                                           2.389134                       \
# 1                                           2.509046
# 2                                           2.721385
# 3                                           2.733676
# 4                                           2.678363
#
#    Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS
# 0                                           0.000190                             \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS
# 0                                           0.000190                      \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS
# 0                                                NaN                             \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  Gini index (World Bank estimate) - SI.POV.GINI
# 0  ...                                             NaN  \
# 1  ...                                             NaN
# 2  ...                                             NaN
# 3  ...                                             NaN
# 4  ...                                             NaN
#
#    Income Classification (World Bank Definition)
# 0                                    High income  \
# 1                                    High income
# 2                                    High income
# 3                                    High income
# 4                                    High income
#
#    Individuals using the Internet (% of population) - IT.NET.USER.ZS
# 0                                                NaN                  \
# 1                                               17.1
# 2                                               18.8
# 3                                               20.8
# 4                                               23.0
#
#    Life expectancy at birth, total (years) - SP.DYN.LE00.IN
# 0                                                NaN         \
# 1                                             73.853
# 2                                             73.937
# 3                                             74.038
# 4                                             74.156
#
#    Population, total - SP.POP.TOTL  Regime Type (RoW Measure Definition)
# 0                              NaN                                   NaN  \
# 1                          92892.0                                   NaN
# 2                          94992.0                                   NaN
# 3                          97016.0                                   NaN
# 4                          98744.0                                   NaN
#
#    Rural population (% of total population) - SP.RUR.TOTL.ZS
# 0                                             53.283          \
# 1                                             53.661
# 2                                             54.028
# 3                                             54.394
# 4                                             54.760
#
#    Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS
# 0                                                NaN             \
# 1                                           0.000712
# 2                                           0.000657
# 3                                           0.000700
# 4                                           0.000685
#
#    Urban population (% of total population) - SP.URB.TOTL.IN.ZS
# 0                                                NaN             \
# 1                                             46.339
# 2                                             45.972
# 3                                             45.606
# 4                                             45.240
#
#    World Regions (UN SDG Definition)
# 0        Latin America and Caribbean
# 1        Latin America and Caribbean
# 2        Latin America and Caribbean
# 3        Latin America and Caribbean
# 4        Latin America and Caribbean
#
# [5 rows x 54 columns]
#   Country Name  Year
# 0        Aruba  2000  \
# 1        Aruba  2001
# 2        Aruba  2002
# 3        Aruba  2003
# 4        Aruba  2004
#
#    Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS
# 0                                          70.792132          \
# 1                                          74.338086
# 2                                          77.553957
# 3                                          78.551686
# 4                                          74.705440
#
#    Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS
# 0                                             0.1753                                    \
# 1                                             0.1805
# 2                                             0.1814
# 3                                             0.1846
# 4                                             0.1871
#
#    Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes
# 0                                              2.378                                      \
# 1                                              2.407
# 2                                              2.437
# 3                                              2.561
# 4                                              2.616
#
#        Continent Income Classification (World Bank Definition)
# 0  North America                                   High income
# 1  North America                                   High income
# 2  North America                                   High income
# 3  North America                                   High income
# 4  North America                                   High income
#   Country Name  Year  Final Consumption  Renewable Energy Consumption
# 0        Aruba  2000          70.792132                        0.1753  \
# 1        Aruba  2001          74.338086                        0.1805
# 2        Aruba  2002          77.553957                        0.1814
# 3        Aruba  2003          78.551686                        0.1846
# 4        Aruba  2004          74.705440                        0.1871
#
#    Annual CO2 Emissions      Continent Income Classification
# 0                 2.378  North America           High income
# 1                 2.407  North America           High income
# 2                 2.437  North America           High income
# 3                 2.561  North America           High income
# 4                 2.616  North America           High income
#        Continent Country Name Income Classification  Year
# 0  North America        Aruba           High income  2000  \
# 1  North America        Aruba           High income  2001
# 2  North America        Aruba           High income  2002
# 3  North America        Aruba           High income  2003
# 4  North America        Aruba           High income  2004
#
#    Annual CO2 Emissions  Renewable Energy Consumption  Final Consumption
# 0                 2.378                        0.1753          70.792132
# 1                 2.407                        0.1805          74.338086
# 2                 2.437                        0.1814          77.553957
# 3                 2.561                        0.1846          78.551686
# 4                 2.616                        0.1871          74.705440
# Continent                         2
# Country Name                      0
# Income Classification             2
# Year                              0
# Annual CO2 Emissions              2
# Renewable Energy Consumption      0
# Final Consumption               240
# dtype: int64
#               Year  Annual CO2 Emissions  Renewable Energy Consumption
# count  3287.000000           3285.000000                   3287.000000  \
# mean   2009.000000            174.646907                     32.672923
# std       5.478059            757.653194                     29.921274
# min    2000.000000              0.048000                      0.000000
# 25%    2004.000000              2.426000                      6.835400
# 50%    2009.000000             12.621000                     22.659800
# 75%    2014.000000             72.012000                     54.638100
# max    2018.000000           9956.569000                     98.342903
#
#        Final Consumption
# count        3047.000000
# mean           80.410827
# std            19.334168
# min            16.712957
# 25%            71.261800
# 50%            79.509708
# 75%            89.748636
# max           241.973940
# (3287, 7)
# Continent      Year
# Africa         2000    65.081958
#                2001    64.630059
#                2002    64.341547
#                2003    63.780913
#                2004    63.205947
#                          ...
# South America  2014    27.546450
#                2015    27.524333
#                2016    27.912391
#                2017    28.361892
#                2018    28.009266
# Name: Renewable Energy Consumption, Length: 114, dtype: float64

# %%
"""World Sustainability Dataset"""
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# read csv and assign it to variable df
df = pd.read_csv(
    "/workspaces/Data-Analysis-with-Python/Project/WorldSustainabilityDataset.csv"
)
print(df.head())

# only keep country name, year, final consumption expenditure, renewable energy consumption,
# annual CO2 emissions, continent, and income classification
df = df[
    [
        "Country Name",
        "Year",
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes",
        "Continent",
        "Income Classification (World Bank Definition)",
    ]
]

print(df.head())

# rename columns
df.rename(
    columns={
        "Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS": "Final Consumption",
        "Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS": "Renewable Energy Consumption",
        "Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes": "Annual CO2 Emissions",
        "Income Classification (World Bank Definition)": "Income Classification",
    },
    inplace=True,
)

print(df.head())

# rearrange columns
df = df[
    [
        "Continent",
        "Country Name",
        "Income Classification",
        "Year",
        "Annual CO2 Emissions",
        "Renewable Energy Consumption",
        "Final Consumption",
    ]
]

print(df.head())

# check to see how many null objects are in the dataset
print(df.isnull().sum())

# quick summary of each column in the dataframe
print(df.describe())

# data dimensions
print(df.shape)

# calculate mean of renewable energy consumption grouped by continent and year
print(df.groupby(["Continent", "Year"])["Renewable Energy Consumption"].mean())

# add mean column
df["REC Mean"] = df.groupby(["Continent", "Year"])["Renewable Energy Consumption"].transform("mean")
print(df)
# Out:
#   Country Name Country Code  Year
# 0        Aruba          ABW  2000  \
# 1        Aruba          ABW  2001
# 2        Aruba          ABW  2002
# 3        Aruba          ABW  2003
# 4        Aruba          ABW  2004
#
#    Access to electricity (% of population) - EG.ELC.ACCS.ZS
# 0                                          91.660398         \
# 1                                         100.000000
# 2                                         100.000000
# 3                                         100.000000
# 4                                         100.000000
#
#    Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS
# 0                                          15.392211                                           \
# 1                                          11.491930
# 2                                           3.893620
# 3                                           6.713863
# 4                                           9.801576
#
#    Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS
# 0                                           2.389134                       \
# 1                                           2.509046
# 2                                           2.721385
# 3                                           2.733676
# 4                                           2.678363
#
#    Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS
# 0                                           0.000190                             \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS
# 0                                           0.000190                      \
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS
# 0                                                NaN                             \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  Gini index (World Bank estimate) - SI.POV.GINI
# 0  ...                                             NaN  \
# 1  ...                                             NaN
# 2  ...                                             NaN
# 3  ...                                             NaN
# 4  ...                                             NaN
#
#    Income Classification (World Bank Definition)
# 0                                    High income  \
# 1                                    High income
# 2                                    High income
# 3                                    High income
# 4                                    High income
#
#    Individuals using the Internet (% of population) - IT.NET.USER.ZS
# 0                                                NaN                  \
# 1                                               17.1
# 2                                               18.8
# 3                                               20.8
# 4                                               23.0
#
#    Life expectancy at birth, total (years) - SP.DYN.LE00.IN
# 0                                                NaN         \
# 1                                             73.853
# 2                                             73.937
# 3                                             74.038
# 4                                             74.156
#
#    Population, total - SP.POP.TOTL  Regime Type (RoW Measure Definition)
# 0                              NaN                                   NaN  \
# 1                          92892.0                                   NaN
# 2                          94992.0                                   NaN
# 3                          97016.0                                   NaN
# 4                          98744.0                                   NaN
#
#    Rural population (% of total population) - SP.RUR.TOTL.ZS
# 0                                             53.283          \
# 1                                             53.661
# 2                                             54.028
# 3                                             54.394
# 4                                             54.760
#
#    Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS
# 0                                                NaN             \
# 1                                           0.000712
# 2                                           0.000657
# 3                                           0.000700
# 4                                           0.000685
#
#    Urban population (% of total population) - SP.URB.TOTL.IN.ZS
# 0                                                NaN             \
# 1                                             46.339
# 2                                             45.972
# 3                                             45.606
# 4                                             45.240
#
#    World Regions (UN SDG Definition)
# 0        Latin America and Caribbean
# 1        Latin America and Caribbean
# 2        Latin America and Caribbean
# 3        Latin America and Caribbean
# 4        Latin America and Caribbean
#
# [5 rows x 54 columns]
#   Country Name  Year
# 0        Aruba  2000  \
# 1        Aruba  2001
# 2        Aruba  2002
# 3        Aruba  2003
# 4        Aruba  2004
#
#    Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS
# 0                                          70.792132          \
# 1                                          74.338086
# 2                                          77.553957
# 3                                          78.551686
# 4                                          74.705440
#
#    Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS
# 0                                             0.1753                                    \
# 1                                             0.1805
# 2                                             0.1814
# 3                                             0.1846
# 4                                             0.1871
#
#    Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes
# 0                                              2.378                                      \
# 1                                              2.407
# 2                                              2.437
# 3                                              2.561
# 4                                              2.616
#
#        Continent Income Classification (World Bank Definition)
# 0  North America                                   High income
# 1  North America                                   High income
# 2  North America                                   High income
# 3  North America                                   High income
# 4  North America                                   High income
#   Country Name  Year  Final Consumption  Renewable Energy Consumption
# 0        Aruba  2000          70.792132                        0.1753  \
# 1        Aruba  2001          74.338086                        0.1805
# 2        Aruba  2002          77.553957                        0.1814
# 3        Aruba  2003          78.551686                        0.1846
# 4        Aruba  2004          74.705440                        0.1871
#
#    Annual CO2 Emissions      Continent Income Classification
# 0                 2.378  North America           High income
# 1                 2.407  North America           High income
# 2                 2.437  North America           High income
# 3                 2.561  North America           High income
# 4                 2.616  North America           High income
#        Continent Country Name Income Classification  Year
# 0  North America        Aruba           High income  2000  \
# 1  North America        Aruba           High income  2001
# 2  North America        Aruba           High income  2002
# 3  North America        Aruba           High income  2003
# 4  North America        Aruba           High income  2004
#
#    Annual CO2 Emissions  Renewable Energy Consumption  Final Consumption
# 0                 2.378                        0.1753          70.792132
# 1                 2.407                        0.1805          74.338086
# 2                 2.437                        0.1814          77.553957
# 3                 2.561                        0.1846          78.551686
# 4                 2.616                        0.1871          74.705440
# Continent                         2
# Country Name                      0
# Income Classification             2
# Year                              0
# Annual CO2 Emissions              2
# Renewable Energy Consumption      0
# Final Consumption               240
# dtype: int64
#               Year  Annual CO2 Emissions  Renewable Energy Consumption
# count  3287.000000           3285.000000                   3287.000000  \
# mean   2009.000000            174.646907                     32.672923
# std       5.478059            757.653194                     29.921274
# min    2000.000000              0.048000                      0.000000
# 25%    2004.000000              2.426000                      6.835400
# 50%    2009.000000             12.621000                     22.659800
# 75%    2014.000000             72.012000                     54.638100
# max    2018.000000           9956.569000                     98.342903
#
#        Final Consumption
# count        3047.000000
# mean           80.410827
# std            19.334168
# min            16.712957
# 25%            71.261800
# 50%            79.509708
# 75%            89.748636
# max           241.973940
# (3287, 7)
# Continent      Year
# Africa         2000    65.081958
#                2001    64.630059
#                2002    64.341547
#                2003    63.780913
#                2004    63.205947
#                          ...
# South America  2014    27.546450
#                2015    27.524333
#                2016    27.912391
#                2017    28.361892
#                2018    28.009266
# Name: Renewable Energy Consumption, Length: 114, dtype: float64
#           Continent Country Name Income Classification  Year
# 0     North America        Aruba           High income  2000  \
# 1     North America        Aruba           High income  2001
# 2     North America        Aruba           High income  2002
# 3     North America        Aruba           High income  2003
# 4     North America        Aruba           High income  2004
# ...             ...          ...                   ...   ...
# 3282         Africa     Zimbabwe            Low income  2014
# 3283         Africa     Zimbabwe            Low income  2015
# 3284         Africa     Zimbabwe            Low income  2016
# 3285         Africa     Zimbabwe            Low income  2017
# 3286         Africa     Zimbabwe            Low income  2018
#
#       Annual CO2 Emissions  Renewable Energy Consumption  Final Consumption
# 0                    2.378                      0.175300          70.792132  \
# 1                    2.407                      0.180500          74.338086
# 2                    2.437                      0.181400          77.553957
# 3                    2.561                      0.184600          78.551686
# 4                    2.616                      0.187100          74.705440
# ...                    ...                           ...                ...
# 3282                11.973                     80.775002         103.172100
# 3283                12.170                     81.427200         108.392819
# 3284                10.815                     82.792603         101.470591
# 3285                10.247                     83.492996          93.411534
# 3286                11.341                     81.363602          62.721238
#
#        REC Mean
# 0     24.879473
# 1     23.560259
# 2     23.904236
# 3     23.350859
# 4     23.843573
# ...         ...
# 3282  59.635864
# 3283  59.129353
# 3284  58.545687
# 3285  58.256121
# 3286  57.774613
#
# [3287 rows x 8 columns]
